# %% [markdown]
# # nmi | 2024 spring
# ## lecture 06 : systems of equations : iterative

# %% [markdown]
# why stop at one? part two.
# </br>

# %% [markdown]
# ### 2.5 iterative methods

# %% [markdown]
# gauss elimination is a finite sequence of $\mathcal{O}(n^3)$ operations that result in a solution. ie, it is a direct method. iterative methods solve systems of linear equations by refining an initial guess.
# </br>

# %% [markdown]
# #### 2.5.1 jacobi method

# %% [markdown]
# jacobi is fixed-point iteration for a system of equations and FPI rewrites equations then solves for the unknown.
# </br>

# %% [markdown]
# ##### ex 19

# %% [markdown]
# apply jacobi to system $3u + v = 5, u + 2v=5$ starting with $(u_0,v_0) = (0,0)$. solve first equation for $u$ first.
# </br></br>
#
# \begin{align}
#   u &= \frac{5-v}{3} \\
#   v &= \frac{5-u}{2}
# \end{align}
# </br>
#
# \begin{align}
#   \begin{bmatrix} u_0 \\ v_0 \end{bmatrix}
#   &= \begin{bmatrix} 0 \\ 0 \end{bmatrix} \\
#   \begin{bmatrix} u_1 \\ v_1 \end{bmatrix}
#   &= \begin{bmatrix} \frac{5-v_0}{3} \\ \frac{5-u_0}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{5-0}{3} \\ \frac{5-0}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{5}{3} \\ \frac{5}{2} \end{bmatrix} \\
#   \begin{bmatrix} u_2 \\ v_2 \end{bmatrix}
#   &= \begin{bmatrix} \frac{5-v_1}{3} \\ \frac{5-u_1}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{5-\frac{5}{2}}{3} \\ \frac{5-\frac{5}{3}}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{5}{6} \\ \frac{5}{3} \end{bmatrix} \\
#   \begin{bmatrix} u_3 \\ v_3 \end{bmatrix}
#   &= \begin{bmatrix} \frac{5-v_2}{3} \\ \frac{5-u_2}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{5-\frac{5}{3}}{3} \\ \frac{5-\frac{5}{6}}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{10}{9} \\ \frac{25}{12} \end{bmatrix}.
# \end{align}
# </br>
#
# further steps show convergence to solution, $[1,2]^T$.

# %% [markdown]
# ##### ex 20

# %% [markdown]
# apply jacobi to system $u + 2v=5, 3u + v = 5$ starting with $(u_0,v_0) = (0,0)$. same equations, flip the order before solving for $u$.
# </br></br>
#
# \begin{align}
#   u &= 5 - 2v \\
#   v &= 5 - 3u
# \end{align}
# </br>
#
# \begin{align}
#   \begin{bmatrix} u_0 \\ v_0 \end{bmatrix}
#   &= \begin{bmatrix} 0 \\ 0 \end{bmatrix} \\
#   \begin{bmatrix} u_1 \\ v_1 \end{bmatrix}
#   &= \begin{bmatrix} 5 - 2v_0 \\ 5 - 3u_0 \end{bmatrix}
#   = \begin{bmatrix} 5 - 2(0) \\ 5 - 3(0) \end{bmatrix}
#   = \begin{bmatrix} 5 \\ 5 \end{bmatrix} \\
#   \begin{bmatrix} u_2 \\ v_2 \end{bmatrix}
#   &= \begin{bmatrix} 5 - 2v_1 \\ 5 - 3u_1 \end{bmatrix}
#   = \begin{bmatrix} 5 - 2(5) \\ 5 - 3(5) \end{bmatrix}
#   = \begin{bmatrix} -5 \\ -10 \end{bmatrix} \\
#   \begin{bmatrix} u_3 \\ v_3 \end{bmatrix}
#   &= \begin{bmatrix} 5 - 2v_2 \\ 5 - 3u_2 \end{bmatrix}
#   = \begin{bmatrix} 5 - 2(-10) \\ 5 - 3(-5) \end{bmatrix}
#   = \begin{bmatrix} 25 \\ 20 \end{bmatrix}.
# \end{align}
# </br>
#
# obviously, this one is not your bff. you need some rules.
# </br>

# %% [markdown]
# <b><font color=grey>def 09</font></b> $n\times n$ matrix $A = (a_{ii})$ is <b>strictly diagonally dominant</b> if for each $1\le i\le n, |a_{ii}| > \sum_{j\ne i} |a_{ij}|$.
# </br>

# %% [markdown]
# <b><font color=grey>th 10</font></b> if $n\times n$ matrix $A$ is strictly diagonally dominant, then (1) $A$ is nonsingular and (2) for every vector $b$ and every starting guess, the jacobi method applied to $Ax=b$ converges to the (unique) solution.
# </br>

# %% [markdown]
# ##### ex 21

# %% [markdown]
# $$
# A =
# \begin{bmatrix}
#   3 & 1 & -1 \\
#   2 & -5 & 2 \\
#   1 & 6 & 8
# \end{bmatrix}
# \text{ and }
# B =
# \begin{bmatrix}
#   3 & 2 & 6 \\
#   1 & 8 & 1 \\
#   9 & 2 & -2
# \end{bmatrix}
# $$
# </br>
#
# where $A$ is and $B$ isnt.
# </br>

# %% [markdown]
# ##### usw

# %% [markdown]
# let $D$ denote main diagonal of $A$, $L$ denote lower triangle of $A$ (below the diagonal) and $U$ denote upper triangle of $A$ (above the triangle) such that $A = L + D + U$. then
# </br></br>
#
# \begin{align}
#   Ax &= b \\
#   (D + L + U)x &= b \\
#   Dx = b - (L+U)x \\
#   x = D^{-1}(b-(L+U)x).
# \end{align}
# </br>

# %% [markdown]
# <b>jacobi method</b>
# </br></br>
#
# \begin{align}
#   x_0 &= \text{initial vector} \\
#   x_{k+1} &= D^{-1}(b-(L+U)x_k) \quad k = 0,1,2,\dots
# \end{align}
# </br>

# %% [markdown]
# ##### ex 19, continued

# %% [markdown]
# \begin{align}
#   \begin{bmatrix} 3 & 1 \\ 1 & 2 \end{bmatrix}
#   \begin{bmatrix} u \\ v \end{bmatrix}
#   &=
#   \begin{bmatrix} 5 \\ 5 \end{bmatrix}
#   \\
#   &\Downarrow \\
#   \\
#   x_k &= \begin{bmatrix} u_k \\ v_k \end{bmatrix} \\
#   \\
#   x_{k+1} &= D^{-1}(b - (L+U)x_k) \\
#   \\
#   &=
#   \begin{bmatrix} \frac{1}{3} & 0 \\ 0 & \frac{1}{2} \end{bmatrix}
#   \left(
#     \begin{bmatrix} 5 \\ 5 \end{bmatrix} -
#     \begin{bmatrix} 0 & 1 \\ 1 & 0 \end{bmatrix}
#     \begin{bmatrix} u_k \\ v_k \end{bmatrix}
#   \right) \\
#   \\
#   &=
#   \begin{bmatrix} \frac{5-v_k}{3} \\\frac{5-u_k}{2} \end{bmatrix}.
# \end{align}
# </br>

# %% [markdown]
# #### gauss-seidel and SOR

# %% [markdown]
# with gauss-seidel, values are used as they are available.
# </br>

# %% [markdown]
# ##### ex 19, continued

# %% [markdown]
# \begin{align}
#   \begin{bmatrix} u_0 \\ v_0 \end{bmatrix}
#   &= \begin{bmatrix} 0 \\ 0 \end{bmatrix}
#   \\
#   \begin{bmatrix} u_1 \\ v_1 \end{bmatrix}
#   &= \begin{bmatrix} \frac{5-v_0}{3} \\\frac{5-u_1}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{5-0}{3} \\ \frac{5-\frac{5}{3}}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{5}{3} \\ \frac{5}{3} \end{bmatrix}
#   \\
#   \begin{bmatrix} u_2 \\ v_2 \end{bmatrix}
#   &= \begin{bmatrix} \frac{5-v_1}{3} \\\frac{5-u_2}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{5-\frac{5}{3}}{3} \\ \frac{5-\frac{10}{9}}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{10}{9} \\ \frac{35}{18} \end{bmatrix}
#   \\
#   \begin{bmatrix} u_3 \\ v_3 \end{bmatrix}
#   &= \begin{bmatrix} \frac{5-v_2}{3} \\\frac{5-u_3}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{5-\frac{35}{18}}{3} \\ \frac{5-\frac{55}{54}}{2} \end{bmatrix}
#   = \begin{bmatrix} \frac{55}{54} \\ \frac{215}{108} \end{bmatrix}.
# \end{align}
# </br>

# %% [markdown]
# ##### usw

# %% [markdown]
# <b>gauss-seidel</b>
# </br></br>
#
# \begin{align}
#   x_0 &= \text{initial vector} \\
#   x_{k+1} &= D^{-1}(b-Ux_k - Lx_{k+1}) \quad k=0,1,2,\dots
# \end{align}
# </br>

# %% [markdown]
# ##### ex 22

# %% [markdown]
# apply gauss-seidel to system
# </br></br>
#
# $$
# \begin{bmatrix} 3 & 1 & -1 \\ 2 & 4 & 1 \\ -1 & 2 & 5 \end{bmatrix}
# \begin{bmatrix} u \\ v \\ w \end{bmatrix}
# =
# \begin{bmatrix} 4 \\ 1 \\ 1 \end{bmatrix}.
# $$
# </br>
#
# iteration:
# </br></br>
#
# \begin{align}
#   u_{k+1} & = \frac{4-v_k+w_k}{3} \\
#   v_{k+1} & = \frac{1-2u_{k+1}-w_k}{4} \\
#   w_{k+1} & = \frac{1+u_{k+1}-2v_{k+1}}{5}
# \end{align}
# </br>
#
# \begin{align}
#   \begin{bmatrix} u_0 \\ v_0 \\ w_0 \end{bmatrix}
#   &= \begin{bmatrix} 0 \\ 0 \\ 0 \end{bmatrix}
#   \\
#   \\
#   \begin{bmatrix} u_1 \\ v_1 \\ w_1 \end{bmatrix}
#   &=
#   \begin{bmatrix}
#     \frac{4-0-0}{3} = \frac{4}{3} \\
#     \frac{1-\frac{8}{3}-0}{4} = -\frac{5}{12} \\
#     \frac{1+\frac{4}{3}+\frac{5}{6}}{5} = \frac{19}{30}
#   \end{bmatrix}
#   \approx \begin{bmatrix} 1.3333 \\ -0.4167 \\ 0.6333 \end{bmatrix}
#   \\
#   \\
#   \begin{bmatrix} u_2 \\ v_2 \\ w_2 \end{bmatrix}
#   &=
#   \begin{bmatrix}
#     \frac{101}{60} \\
#     -\frac{3}{4} \\
#     \frac{251}{300}
#   \end{bmatrix}
#   \approx \begin{bmatrix} 1.6833 \\ -0.7500 \\ 0.8367 \end{bmatrix}
# \end{align}
# </br>
#
# this system is strictly diagonally dominant and will converge to $[2,-1,1]^T$.
# </br>

# %% [markdown]
# further, if weights are applied to gauss-seidel to speed convergence, thats <b>successive over-relaxation (SOR)</b>.
# </br></br>
#
# let $\omega\in\mathbb{R}$ and define each component of new guess $x_{k+1}$ as a weighted average of $\omega$ times gauss-seidel formula and $1-\omega$ times the current guess $x_k$. $\omega$ is the <b>relaxation parameter</b> and $\omega\in[0,2]$. $\omega>1$ is referred to as <b>over-relaxation</b>; and $\omega < 1$ is under-relaxation; and $\omega = 1$ is gauss-seidel, :).
# </br>

# %% [markdown]
# ##### ex 23

# %% [markdown]
# apply SOR with $\omega = 1.25$ to example 22.
# </br></br>
#
# \begin{align}
#   u_{k+1} & = (1-\omega)u_k + \omega\frac{4-v_k+w_k}{3} \\
#   v_{k+1} & = (1-\omega)v_k + \omega\frac{1-2u_{k+1}-w_k}{4} \\
#   w_{k+1} & = (1-\omega)w_k + \omega\frac{1+u_{k+1}-2v_{k+1}}{5}
# \end{align}
# </br>
#
# \begin{align}
#   \begin{bmatrix} u_0 \\ v_0 \\ w_0 \end{bmatrix}
#   &= \begin{bmatrix} 0 \\ 0 \\ 0 \end{bmatrix}
#   \\
#   \\
#   \begin{bmatrix} u_1 \\ v_1 \\ w_1 \end{bmatrix}
#   &\approx \begin{bmatrix} 1.6667 \\ -0.7292 \\ 1.0312 \end{bmatrix}
#   \\
#   \\
#   \begin{bmatrix} u_2 \\ v_2 \\ w_2 \end{bmatrix}
#   &\approx \begin{bmatrix} 1.9835 \\ -1.0672 \\ 1.0216 \end{bmatrix}
# \end{align}
# </br>

# %% [markdown]
# ##### usw

# %% [markdown]
# and
# </br></br>
#
# \begin{align}
#   (\omega L + \omega D + \omega U)x &= \omega b \\
#   (\omega L + D)x &= \omega b - \omega Ux + (1-\omega)Dx \\
#   x &= (\omega L + D)^{-1}[(1-\omega)Dx - \omega Ux] + \omega(D + \omega L)^{-1}b \\ \\
#   &\Downarrow \\ \\
#   \color{red}{\text{no no no!}}\quad x_{k+1} &= (\omega L + D)^{-1}[(1-\omega)Dx_k - \omega Ux_k] + \omega(D + \omega L)^{-1}b \\
# \end{align}
# </br>
#
# this logic bc $(\omega L + D)x$ was previous LHS and $x_{k+1}$ relates to $L$; <font color=red>however</font>, this distorts the impact of $\omega,(1-\omega)$ and does not reflect $x_{k+1} = (1-\omega) x_k + \omega x_{k\text{, gauss seidel}}$. happy birthday!
# </br>

# %% [markdown]
# <b>successive over-relaxation (SOR)</b>
# </br></br>
#
# \begin{align}
#   x_0 &= \text{initial vector} \\
#   x_{k+1} &= \underbrace{(1-\omega)x_k}_{x_k\text{, weighted}} + \underbrace{\omega(D^{-1}(b-Ux_k - Lx_{k+1}))}_{x_{k+1}\text{ (gauss-seidel), weighted}} \quad k=0,1,2,\dots
# \end{align}
# </br>

# %% [markdown]
# also
# </br></br>
#
# * relaxation parameter with gauss-seidel [@themathguy](https://www.youtube.com/watch?v=D3S185K4WWc). (its more complicated than above. but bc i was verifying previous algorithm - ie, preceding red text.)
# </br>

# %% [markdown]
# ##### ex 24

# %% [markdown]
# compare jacobi, gauss-seidel, SOR with system
# </br></br>
#
# $$
# \begin{bmatrix}
#   3 & -1 & 0 & 0 & 0 & \frac{1}{2} \\
#   -1 & 3 & -1 & 0 & \frac{1}{2} & 0 \\
#   0 & -1 & 3 & -1 & 0 & 0 \\
#   0 & 0 & -1 & 3 & -1 & 0 \\
#   0 & \frac{1}{2} & 0 & -1 & 3 & -1 \\
#   \frac{1}{2} & 0 & 0 & 0 & -1 & 3
# \end{bmatrix}
# \begin{bmatrix} u_1 \\ u_2 \\ u_3 \\ u_4 \\ u_5 \\ u_6 \end{bmatrix}
# =
# \begin{bmatrix}
#   \frac{5}{2} \\ \frac{3}{2} \\ 1 \\
#   1 \\ \frac{3}{2} \\ \frac{5}{2}
# \end{bmatrix}
# .
# $$
# </br>
#
# solution is $x=[1,1,1,1,1,1]^T$. $x$ at six iterations below.
# </br>

# %% [markdown]
# ##### code

# %%
# lol, no. not this problem but its code is homework.

# %% [markdown]
# ###### results, reference

# %% [markdown]
# ![ss_sauer2_02_x24.png](data:image/png;base64,...)
# </br></br></br></br></br>
# </br></br></br></br></br>

# %% [markdown]
# ![ss_sauer2_02_f03.png](data:image/png;base64,...)

# %% [markdown]
# ##### results

# %% [markdown]
# ![nmi_06_0202_x24_1.png](data:image/png;base64,...)

# %% [markdown]
# ![nmi_06_0202_x24_4.png](data:image/png;base64,...)

# %% [markdown]
# ![nmi_06_0202_x24_2.png](data:image/png;base64,...)

# %% [markdown]
# #### 2.5.3 convergence

# %% [markdown]
# why approximate with iterative methods vs solve directly with gaussian elimination methods? bc its operationally cheaper. its even more so if starting with a good guess.
# </br></br>
#
# iterative methods also avoid the bleed over that happens with sparse matrices that implement gauss elimination. (there are also structures for sparse matrices.)
# </br>
