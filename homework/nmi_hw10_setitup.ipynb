# %% [markdown]
# # nmi | spring 2024
# ## homework 10 | problem set-up
# ## your name here

# %% [markdown]
# ### q1 (20 pts) systems of equations for IVP.

# %% [markdown]
# express each higher order derivative as a system of equations to solve as IVP.
# </br></br>
#
# in each case, $y(0) = 1, t\in [0,1]$.
# </br>

# %% [markdown]
# a) $y'' = t^2, y'(0) = 0$.

# %% [markdown]
# b) $y'' = 2(t+1), y'(0) = 2$.

# %% [markdown]
# c) $y'' = 5t^4, y'(0) = 0$.

# %% [markdown]
# d) $y''' = \frac{6}{y^4}, y'(0) = 1, y''(0) = -2$.

# %% [markdown]
# ### q2 (15 pts) step of integration.

# %% [markdown]
# ie,
# </br></br>
#
# \begin{align}
#   w_0 &= y_0 \\
#   w_{i+i} &= w_i + hf \dots
# \end{align}
# </br>
#
# provide fully expanded $w_{i+1}$ for $i\ge 0$.

# %% [markdown]
# <b><font color=red>answer any below for total of 15 pts</font></b>

# %% [markdown]
# a) (5 pts) express the expanded step expression for any system of q1 using eulers method.

# %% [markdown]
# b) (5 pts) express the expanded step expression for any system of q1 using trapezoidal method.

# %% [markdown]
# c) (5 pts) express the expanded step expression for any system of q1 using midpoint method.

# %% [markdown]
# d) (10 pts) express the expanded step expression for any system of q1 using RK4.

# %% [markdown]
# ### q3 (10 pts) classical physics.

# %% [markdown]
# express, as the solution of a second-order boundary value problem, the height of a projectile that is thrown from the top of a $60$-meter tall building and takes $5$ seconds to reach the ground. solve the problem (this can be done without code) and find the maximum height reached by the projectile.

# %% [markdown]
# ### q4 (20 pts) FDM.

# %% [markdown]
# #### a) (10 pts) provide discretized form of linear BVP.

# %% [markdown]
# \begin{align}
#   \left\{
#     \begin{array}
#       && y'' = y + \frac{2}{3}e^t \\
#       & y(0) = 0 \\
#       & y(1) = \frac{1}{3}e.
#     \end{array}
#   \right.
# \end{align}
# </br>

# %% [markdown]
# #### b) (10 pts) provide discretized form of nonlinear BVP.

# %% [markdown]
# \begin{align}
#   \left\{
#     \begin{array}
#       && y'' = 18y^2 \\
#       & y(1) = \frac{1}{3} \\
#       & y(2) = \frac{1}{12}.
#     \end{array}
#   \right.
# \end{align}
# </br>
